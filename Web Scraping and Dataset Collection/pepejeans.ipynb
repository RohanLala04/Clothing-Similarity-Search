# %%
import selenium
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

# Function to crawl a web page and return the parsed HTML using Selenium and BeautifulSoup
def crawler(link, user_agent, chromedriver_path):
    # Configure Selenium options
    options = webdriver.ChromeOptions()
    options.headless = True
    options.add_argument(f'user-agent={user_agent}')
    options.add_argument("--window-size=1920,1080")
    options.add_argument('--ignore-certificate-errors')
    options.add_argument('--allow-running-insecure-content')
    options.add_argument("--disable-extensions")
    options.add_argument("--proxy-server='direct://'")
    options.add_argument("--proxy-bypass-list=*")
    options.add_argument("--start-maximized")
    options.add_argument('--disable-gpu')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--no-sandbox')
    
    # Create a WebDriver instance with the configured options
    driver = webdriver.Chrome(executable_path=chromedriver_path, options=options)
    
    # Wait for a short duration to ensure the WebDriver is ready
    time.sleep(0.5)
    
    # Open the specified link in the WebDriver
    driver.get(link)
    
    # Scroll down the page in increments of 100 pixels
    height = driver.execute_script("return document.body.scrollHeight")
    for scrol in range(100, height, 100):
        driver.execute_script(f"window.scrollTo(0, {scrol})")
        time.sleep(0.3)
    
    # Get the page source after scrolling
    src = driver.page_source
    
    # Parse the HTML source using BeautifulSoup
    tango = bs(src.encode("utf-8"), "html")
    
    # Quit the WebDriver instance
    driver.quit()
    
    # Return the parsed HTML
    return tango

# Input parameters
link = 'https://www.pepejeans.in/women/clothing'
user_agent = "YOUR_USER_AGENT"
chromedriver_path = r'C:\Program Files (x86)\chromedriver'

# Call the crawler function
soup = crawler(link, user_agent, chromedriver_path)

# Find the elements containing product titles and links
product_titles = soup.find_all('a', class_='link')
product_links = ["https://www.pepejeans.in" + link['href'] for link in product_titles]

# Extract the text from the product titles
product_titles_text = [title.text.strip() for title in product_titles]

# Print or further process the extracted data
for title, link in zip(product_titles_text, product_links):
    print(f"Product Title: {title}")
    print(f"Product Link: {link}")
    print()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_10992\205419601.py:9: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_10992\205419601.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path, options=options)
# Product Title: Jandra Floral Printed Dress
# Product Link: https://www.pepejeans.in/jandra-floral-printed-dress/8905074915415.html
#
# Product Title: Dace Sr Cavillary Twill Shirtdress
# Product Link: https://www.pepejeans.in/dace-sr-cavillary-twill-shirtdress/8905074919178.html
#
# Product Title: Prixton Soft Voile Printed Mini Dress
# Product Link: https://www.pepejeans.in/prixton-soft-voile-printed-mini-dress/8905074915613.html
#
# Product Title: Trendy Tie Effect Denim Jacket
# Product Link: https://www.pepejeans.in/trendy-tie-effect-denim-jacket/8905074931668.html
#
# Product Title: Multi Color Tie Dye T-shirt
# Product Link: https://www.pepejeans.in/multi-color-tie-dye-t-shirt/8905074928583.html
#
# Product Title: Blue Tie & Dye Hooded T-shirt
# Product Link: https://www.pepejeans.in/blue-tie-and-dye-hooded-t-shirt/8905074917938.html
#
# Product Title: Trucker Denim Jacket
# Product Link: https://www.pepejeans.in/trucker-denim-jacket/8905074931736.html
#
# Product Title: Solid White T-shirt With Mesh Detail
# Product Link: https://www.pepejeans.in/solid-white-t-shirt-with-mesh-detail/8905074918256.html
#
# Product Title: JOSEFIN PRINTED HIGH WAIST SHORTS
# Product Link: https://www.pepejeans.in/josefin-printed-high-waist-shorts/8905074918614.html
#
# Product Title: Stylish Color Block Crop Shirt
# Product Link: https://www.pepejeans.in/stylish-color-block-crop-shirt/8905074925445.html
#
# Product Title: Multi Color Printed Top
# Product Link: https://www.pepejeans.in/multi-color-printed-top/8905074863396.html
#
# Product Title: Lilac Solid Crop Shirt
# Product Link: https://www.pepejeans.in/lilac-solid-crop-shirt/8905074863952.html
#
# Product Title: Red Checks Hoodie Shirt
# Product Link: https://www.pepejeans.in/red-checks-hoodie-shirt/8905074863631.html
#
# Product Title: Blue Checks Roll Up Sleeve Shirt
# Product Link: https://www.pepejeans.in/blue-checks-roll-up-sleeve-shirt/8905074925520.html
#
# Product Title: Green Crop T-Shirt
# Product Link: https://www.pepejeans.in/green-crop-t-shirt/8905074929269.html
#
# Product Title: Green Crop T-Shirt
# Product Link: https://www.pepejeans.in/green-crop-t-shirt/8905074929306.html
#
# Product Title: Crop Full Sleeve Check Shirt
# Product Link: https://www.pepejeans.in/crop-full-sleeve-check-shirt/8905074863914.html
#
# Product Title: Crop Cut out Pink T-Shirt
# Product Link: https://www.pepejeans.in/crop-cut-out-pink-t-shirt/8905074918010.html
#
# Product Title: Crop Cut out Pink T-Shirt
# Product Link: https://www.pepejeans.in/crop-cut-out-pink-t-shirt/8905074918058.html
#
# Product Title: Trendy Rib Black Crop Top
# Product Link: https://www.pepejeans.in/trendy-rib-black-crop-top/8905074928507.html
#
# Product Title: Trendy Rib Black Crop Top
# Product Link: https://www.pepejeans.in/trendy-rib-black-crop-top/8905074928545.html
#
# Product Title: Light Wash Crop Denim Shirt
# Product Link: https://www.pepejeans.in/light-wash-crop-denim-shirt/8905074863358.html
#
# Product Title: Big Pockets Oversized Pink Shirt
# Product Link: https://www.pepejeans.in/big-pockets-oversized-pink-shirt/8905074858170.html
#
# Product Title: Kingsman Pure Linen Shirt
# Product Link: https://www.pepejeans.in/kingsman-pure-linen-shirt/8905074693597.html
#
# Product Title: Kingsman Slim Fit Pure Linen Shirt
# Product Link: https://www.pepejeans.in/kingsman-slim-fit-pure-linen-shirt/8905074722099.html
#
# Product Title: Roy Logo Printed Stretch Tshirt
# Product Link: https://www.pepejeans.in/roy-logo-printed-stretch-tshirt/8905074632961.html
#
# Product Title: Dallas Solid Dobby Shirt
# Product Link: https://www.pepejeans.in/dallas-solid-dobby-shirt/8905074617401.html

# %%
import pandas as pd

# Create a DataFrame from the lists
df = pd.DataFrame({'Product_Description': product_titles_text, 'Product_Link': product_links})

df.tail()
# Out:
#                    Product_Description  \
# 47    Big Pockets Oversized Pink Shirt
# 48           Kingsman Pure Linen Shirt
# 49  Kingsman Slim Fit Pure Linen Shirt
# 50     Roy Logo Printed Stretch Tshirt
# 51            Dallas Solid Dobby Shirt
#
#                                          Product_Link
# 47  https://www.pepejeans.in/big-pockets-oversized...
# 48  https://www.pepejeans.in/kingsman-pure-linen-s...
# 49  https://www.pepejeans.in/kingsman-slim-fit-pur...
# 50  https://www.pepejeans.in/roy-logo-printed-stre...
# 51  https://www.pepejeans.in/dallas-solid-dobby-sh...

# %%
# Save the DataFrame to a CSV file
df.to_csv('pepejeans_output.csv', index=False)
