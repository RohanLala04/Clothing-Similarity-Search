# %%
import selenium
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

# Function to crawl a web page and return the parsed HTML using Selenium and BeautifulSoup
def crawler(link, user_agent, chromedriver_path):
    # Configure Selenium options
    options = webdriver.ChromeOptions()
    options.headless = True
    options.add_argument(f'user-agent={user_agent}')
    options.add_argument("--window-size=1920,1080")
    options.add_argument('--ignore-certificate-errors')
    options.add_argument('--allow-running-insecure-content')
    options.add_argument("--disable-extensions")
    options.add_argument("--proxy-server='direct://'")
    options.add_argument("--proxy-bypass-list=*")
    options.add_argument("--start-maximized")
    options.add_argument('--disable-gpu')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--no-sandbox')
    
    # Create a WebDriver instance with the configured options
    driver = webdriver.Chrome(executable_path=chromedriver_path, options=options)
    
    # Wait for a short duration to ensure the WebDriver is ready
    time.sleep(0.5)
    
    # Open the specified link in the WebDriver
    driver.get(link)
    
    # Scroll down the page in increments of 100 pixels
    height = driver.execute_script("return document.body.scrollHeight")
    for scrol in range(100, height, 100):
        driver.execute_script(f"window.scrollTo(0, {scrol})")
        time.sleep(0.3)
    
    # Get the page source after scrolling
    src = driver.page_source
    
    # Parse the HTML source using BeautifulSoup
    tango = bs(src.encode("utf-8"), "html")
    
    # Quit the WebDriver instance
    driver.quit()
    
    # Return the parsed HTML
    return tango

# Input parameters
link = 'https://www.zara.com/in/en/woman-shirts-event-l1219.html?v1=2050374'
user_agent = "YOUR_USER_AGENT"
chromedriver_path = r'C:\Program Files (x86)\chromedriver'

# Call the crawler function
soup = crawler(link, user_agent, chromedriver_path)

# Find the elements containing product titles and links
product_titles = soup.find_all('a', class_='product-link _item product-grid-product-info__name link')
product_links = [link['href'] for link in product_titles] 
# Extract the text from the product titles
product_titles_text = [title.text.strip() for title in product_titles]

# Print or further process the extracted data
for title, link in zip(product_titles_text, product_links):
    print(f"Product Title: {title}")
    print(f"Product Link: {link}")
    print()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_24036\1965689650.py:9: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_24036\1965689650.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path, options=options)
# Product Title: HIGH-WAIST TROUSERS
# Product Link: https://www.zara.com/in/en/high-waist-trousers-p02162888.html
#
# Product Title: LONG FLOWING TROUSERS
# Product Link: https://www.zara.com/in/en/long-flowing-trousers-p02731271.html
#
# Product Title: HIGH-WAIST TROUSERS
# Product Link: https://www.zara.com/in/en/high-waist-trousers-p02162888.html
#
# Product Title: LINEN BLEND PRINTED SHORT DRESS
# Product Link: https://www.zara.com/in/en/linen-blend-printed-short-dress-p03297441.html
#
# Product Title: Z1975 HIGH-RISE STRAIGHT JEANS
# Product Link: https://www.zara.com/in/en/z1975-high-rise-straight-jeans-p06164023.html
# Product Link: https://www.zara.com/in/en/linen-blend-midi-dress-p02309378.html
#
# Product Title: HIGH-HEEL SLINGBACK SHOES WITH FAUX PEARLS
# Product Link: https://www.zara.com/in/en/high-heel-slingback-shoes-with-faux-pearls-p12815110.html
#
# Product Title: SHORT DAISY DRESS
# Product Link: https://www.zara.com/in/en/short-daisy-dress-p07521331.html
#
# Product Title: ZW DENIM CORSET WITH SLIT
# Product Link: https://www.zara.com/in/en/zw-denim-corset-with-slit-p02553070.html
#
# Product Title: LINEN BLEND PRINTED SHIRT
# Product Link: https://www.zara.com/in/en/linen-blend-printed-shirt-p03394339.html
#
# Product Title: FLARED TROUSERS
# Product Link: https://www.zara.com/in/en/flared-trousers-p01478343.html
#
# Product Title: LINEN WIDE-LEG TROUSERS
# Product Link: https://www.zara.com/in/en/linen-wide-leg-trousers-p08372098.html
#
# Product Title: FLAT VINYL PEARL BEAD SANDALS
# Product Link: https://www.zara.com/in/en/flat-vinyl-pearl-bead-sandals-p12611110.html
#
# Product Title: STRAIGHT TROUSERS WITH METAL BUTTONS
# Product Link: https://www.zara.com/in/en/straight-trousers-with-metal-buttons-p09929020.html
#
# Product Title: TRF WIDE-LEG HIGH-WAIST RIPPED JEANS
# Product Link: https://www.zara.com/in/en/trf-wide-leg-high-waist-ripped-jeans-p08197227.html
#
# Product Title: HIGH-WAIST MINI SKIRT
# Product Link: https://www.zara.com/in/en/high-waist-mini-skirt-p04043040.html
#
# Product Title: CROSSOVER TOP WITH TIE DETAIL
# Product Link: https://www.zara.com/in/en/crossover-top-with-tie-detail-p07484085.html
#
# Product Title: PRINTED DRESS WITH ASYMMETRIC HEM
# Product Link: https://www.zara.com/in/en/printed-dress-with-asymmetric-hem-p03515355.html
#
# Product Title: LINEN WIDE-LEG TROUSERS
# Product Link: https://www.zara.com/in/en/linen-wide-leg-trousers-p08372373.html
#
# Product Title: POPLIN SHIRT
# Product Link: https://www.zara.com/in/en/poplin-shirt-p04387036.html
#
# Product Title: SATIN FLORAL SHIRT
# Product Link: https://www.zara.com/in/en/satin-floral-shirt-p07969235.html

# %%
import pandas as pd

# Create a DataFrame from the lists
df = pd.DataFrame({'Product_Description': product_titles_text, 'Product_Link': product_links})

df.tail()
# Out:
#                    Product_Description  \
# 145      CROSSOVER TOP WITH TIE DETAIL
# 146  PRINTED DRESS WITH ASYMMETRIC HEM
# 147            LINEN WIDE-LEG TROUSERS
# 148                       POPLIN SHIRT
# 149                 SATIN FLORAL SHIRT
#
#                                           Product_Link
# 145  https://www.zara.com/in/en/crossover-top-with-...
# 146  https://www.zara.com/in/en/printed-dress-with-...
# 147  https://www.zara.com/in/en/linen-wide-leg-trou...
# 148  https://www.zara.com/in/en/poplin-shirt-p04387...
# 149  https://www.zara.com/in/en/satin-floral-shirt-...

# %%
# Save the DataFrame to a CSV file
df.to_csv('zara_output.csv', index=False)
